# %%
import pandas as pd
import numpy as pd

excel_file= 'C:\\Users\\Admin\\Downloads\\movies.xls'
movies=pd.read_excel(excel_file)

movies[(movies['IMDB Score']>8) & (movies['Duration']>200)]
movies['New']=movies['Year']*2
movies
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\Admin\test\test.ipynb Cell 1' in <cell line: 5>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Admin/test/test.ipynb#ch0000000?line=1'>2</a> import numpy as pd
#       <a href='vscode-notebook-cell:/c%3A/Users/Admin/test/test.ipynb#ch0000000?line=3'>4</a> excel_file= 'C:\\Users\\Admin\\Downloads\\movies.xls'
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Admin/test/test.ipynb#ch0000000?line=4'>5</a> movies=pd.read_excel(excel_file)
#       <a href='vscode-notebook-cell:/c%3A/Users/Admin/test/test.ipynb#ch0000000?line=6'>7</a> movies[(movies['IMDB Score']>8) & (movies['Duration']>200)]
#       <a href='vscode-notebook-cell:/c%3A/Users/Admin/test/test.ipynb#ch0000000?line=7'>8</a> movies['New']=movies['Year']*2
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\__init__.py:315, in __getattr__(attr)
#     <a href='file:///c%3A/Users/Admin/AppData/Local/Programs/Python/Python310/lib/site-packages/numpy/__init__.py?line=311'>312</a>     from .testing import Tester
#     <a href='file:///c%3A/Users/Admin/AppData/Local/Programs/Python/Python310/lib/site-packages/numpy/__init__.py?line=312'>313</a>     return Tester
# --> <a href='file:///c%3A/Users/Admin/AppData/Local/Programs/Python/Python310/lib/site-packages/numpy/__init__.py?line=314'>315</a> raise AttributeError("module {!r} has no attribute "
#     <a href='file:///c%3A/Users/Admin/AppData/Local/Programs/Python/Python310/lib/site-packages/numpy/__init__.py?line=315'>316</a>                      "{!r}".format(__name__, attr))
#
# AttributeError: module 'numpy' has no attribute 'read_excel'

# %%
import numpy as np
movies['Pass']=np.where(movies['IMDB Score']>8,'qua','lose')
movies
# Out:
#                                                   Title  Year  \
# 0     Intolerance: Love's Struggle Throughout the Ages   1916
# 1                       Over the Hill to the Poorhouse   1920
# 2                                       The Big Parade   1925
# 3                                           Metropolis   1927
# 4                                        Pandora's Box   1929
# ...                                                 ...   ...
# 1333                                  Twin Falls Idaho   1999
# 1334                     Universal Soldier: The Return   1999
# 1335                                     Varsity Blues   1999
# 1336                                    Wild Wild West   1999
# 1337                                    Wing Commander   1999
#
#                             Genres Language  Country Content Rating  Duration  \
# 0                Drama|History|War      NaN      USA      Not Rated       123
# 1                      Crime|Drama      NaN      USA            NaN       110
# 2                Drama|Romance|War      NaN      USA      Not Rated       151
# 3                     Drama|Sci-Fi   German  Germany      Not Rated       145
# 4              Crime|Drama|Romance   German  Germany      Not Rated       110
# ...                            ...      ...      ...            ...       ...
# 1333                         Drama  English      USA              R       111
# 1334                 Action|Sci-Fi  English      USA              R        83
# 1335    Comedy|Drama|Romance|Sport  English      USA              R       106
# 1336  Action|Comedy|Sci-Fi|Western  English      USA          PG-13       106
# 1337       Action|Adventure|Sci-Fi  English      USA          PG-13       100
#
#       Aspect Ratio       Budget  Gross Earnings  ... Facebook Likes - Actor 3  \
# 0             1.33     385907.0             NaN  ...                      9.0
# 1             1.33     100000.0       3000000.0  ...                      0.0
# 2             1.33     245000.0             NaN  ...                      6.0
# 3             1.33    6000000.0         26435.0  ...                     18.0
# 4             1.33          NaN          9950.0  ...                      3.0
# ...            ...          ...             ...  ...                      ...
# 1333          1.85     500000.0        985341.0  ...                    482.0
# 1334          1.85   24000000.0      10431220.0  ...                    485.0
# 1335          1.85   16000000.0      52885587.0  ...                     35.0
# 1336          1.85  170000000.0     113745408.0  ...                    582.0
# 1337          2.35   30000000.0      11576087.0  ...                    362.0
#
#      Facebook Likes - cast Total Facebook likes - Movie Facenumber in posters  \
# 0                            481                    691                     1
# 1                              4                      0                     1
# 2                            108                    226                     0
# 3                            203                  12000                     1
# 4                            455                    926                     1
# ...                          ...                    ...                   ...
# 1333                        3166                    180                     0
# 1334                        4024                    401                     0
# 1335                       23369                      0                     0
# 1336                       15870                      0                     2
# 1337                        2497                    858                     3
#
#       User Votes  Reviews by Users  Reviews by Crtiics  IMDB Score   New  Pass
# 0          10718                88                69.0         8.0  3832  lose
# 1              5                 1                 1.0         4.8  3840  lose
# 2           4849                45                48.0         8.3  3850   qua
# 3         111841               413               260.0         8.3  3854   qua
# 4           7431                84                71.0         8.0  3858  lose
# ...          ...               ...                 ...         ...   ...   ...
# 1333        3479                87                54.0         7.3  3998  lose
# 1334       24216               162                75.0         4.1  3998  lose
# 1335       35312               267                67.0         6.4  3998  lose
# 1336      129601               648                85.0         4.8  3998  lose
# 1337       14747               338                85.0         4.1  3998  lose
#
# [1338 rows x 27 columns]

# %%
movies.tail(5)
# Out:
#                                Title  Year                        Genres  \
# 1333               Twin Falls Idaho   1999                         Drama
# 1334  Universal Soldier: The Return   1999                 Action|Sci-Fi
# 1335                  Varsity Blues   1999    Comedy|Drama|Romance|Sport
# 1336                 Wild Wild West   1999  Action|Comedy|Sci-Fi|Western
# 1337                 Wing Commander   1999       Action|Adventure|Sci-Fi
#
#      Language Country Content Rating  Duration  Aspect Ratio       Budget  \
# 1333  English     USA              R       111          1.85     500000.0
# 1334  English     USA              R        83          1.85   24000000.0
# 1335  English     USA              R       106          1.85   16000000.0
# 1336  English     USA          PG-13       106          1.85  170000000.0
# 1337  English     USA          PG-13       100          2.35   30000000.0
#
#       Gross Earnings  ... Facebook Likes - Actor 1 Facebook Likes - Actor 2  \
# 1333        985341.0  ...                      980                      505
# 1334      10431220.0  ...                     2000                      577
# 1335      52885587.0  ...                    23000                      255
# 1336     113745408.0  ...                    10000                     4000
# 1337      11576087.0  ...                      811                      586
#
#      Facebook Likes - Actor 3 Facebook Likes - cast Total  \
# 1333                    482.0                        3166
# 1334                    485.0                        4024
# 1335                     35.0                       23369
# 1336                    582.0                       15870
# 1337                    362.0                        2497
#
#       Facebook likes - Movie  Facenumber in posters  User Votes  \
# 1333                     180                      0        3479
# 1334                     401                      0       24216
# 1335                       0                      0       35312
# 1336                       0                      2      129601
# 1337                     858                      3       14747
#
#       Reviews by Users  Reviews by Crtiics  IMDB Score
# 1333                87                54.0         7.3
# 1334               162                75.0         4.1
# 1335               267                67.0         6.4
# 1336               648                85.0         4.8
# 1337               338                85.0         4.1
#
# [5 rows x 25 columns]

# %%
movies[(movies['Genres']=='Drama') & (movies['Content Rating']=='Approved')]
# Out:
#             Title  Year Genres Language Country Content Rating  Duration  \
# 74  Elmer Gantry   1960  Drama  English     USA       Approved       146
# 94           Hud   1963  Drama  English     USA       Approved       112
#
#     Aspect Ratio     Budget  Gross Earnings  ... Facebook Likes - Actor 1  \
# 74          1.66  3000000.0             NaN  ...                      556
# 94          2.35  2500000.0             NaN  ...                      617
#
#    Facebook Likes - Actor 2 Facebook Likes - Actor 3  \
# 74                      422                    125.0
# 94                      189                    124.0
#
#    Facebook Likes - cast Total  Facebook likes - Movie  Facenumber in posters  \
# 74                        1444                     808                      1
# 94                        1141                    1000                      0
#
#     User Votes  Reviews by Users  Reviews by Crtiics  IMDB Score
# 74        7998                81                42.0         7.9
# 94       15277               120                65.0         7.9
#
# [2 rows x 25 columns]

# %%
a=movies[(movies['Year']==1990)&(movies['IMDB Score']>8)]

# %%
 movies['New']=movies['Year']*2
 movies['New']
# Out:
# 0       3832
# 1       3840
# 2       3850
# 3       3854
# 4       3858
#         ...
# 1333    3998
# 1334    3998
# 1335    3998
# 1336    3998
# 1337    3998
# Name: New, Length: 1338, dtype: int64
